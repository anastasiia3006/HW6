# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as norm

# %%
mu_weekday =480
sigma_weekday = 30

p_weekday_over_600 = 1 - norm.cdf(600, loc=mu_weekday, scale=sigma_weekday)
print(f"Probability of more than 600 cars on a weekday: {p_weekday_over_600:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 mu_weekday =480
#       2 sigma_weekday = 30
# ----> 4 p_weekday_over_600 = 1 - norm.cdf(600, loc=mu_weekday, scale=sigma_weekday)
#       5 print(f"Probability of more than 600 cars on a weekday: {p_weekday_over_600:.4f}")
#
# AttributeError: module 'scipy.stats' has no attribute 'cdf'

# %%
mu_weekday = mu_weekday * 1.2
sigma_weekday = sigma_weekday

p_weekday_over_600 = 1 - norm.cdf(600, loc=mu_weekday, scale=sigma_weekday)
print(f"Probability of more than 600 cars on a weekday with 20% increase: {p_weekday_over_600 * 100}%")

x = np.linspace(mu_weekday - 4*sigma_weekday, mu_weekday + 4*sigma_weekday, 1000)
y_weekend
